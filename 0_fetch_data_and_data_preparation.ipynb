# %% [markdown]
# # ETL

# %%
# ! pip install pyarrow

# %% [markdown]
# # Fetch data and data preparation

# %% [markdown]
# I chose data coming from credit card applications and records. The data is downloaded from Kaggle and can be found at https://www.kaggle.com/rikdifos/credit-card-approval-prediction

# %% [markdown]
# ## <font>Download files</font>
#
# <font color="red"> You must first install the Kaggle API CLI by running 'pip install kaggle' and also have the Kaggle credentials (kaggle.json) in the same folder of this NB</font>

# %%
# set up the Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# !pwd
# 
![ -f data/credit-card-approval-prediction.zip ] || pip install kaggle && cd data && kaggle datasets download rikdifos/credit-card-approval-prediction

# !unzip -o data/credit-card-approval-prediction.zip -d data
# Out:
# kaggle.json
# /Users/arosero/afroserom/coursera/IBM_advanced_DS
# credit-card-approval-prediction.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  data/credit-card-approval-prediction.zip
#   inflating: data/application_record.csv
#   inflating: data/credit_record.csv

# %% [markdown]
# ## Settings

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import helpers.settings as sts
sts.print_settings(sts)
# Out:
# BEST_ESTIMATOR_FILENAME : best_estimator_0.0.1.pkl
# DATASET_TRAIN_FILENAME : dataset_train.parquet
# DATASET_VALIDATION_FILENAME : dataset_validation.parquet
# ETL_VERSION : 0.0.1
# MODEL_FILENAME : model.pkl
# MODEL_VERSION : 0.0.1
# PREPROCESSOR_FILENAME : preprocessor_0.0.1.pkl
# TRAINED_BEST_ESTIMATOR_FILENAME : trained_best_estimator_0.0.1.pkl
# color : <class 'helpers.settings.color'>
# print_settings : <function print_settings at 0x7fe99b2e1280>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import RobustScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    classification_report,
    plot_precision_recall_curve,
    precision_recall_curve,
    average_precision_score,
)
from xgboost import XGBClassifier
from category_encoders.woe import WOEEncoder
from sklearn.preprocessing import RobustScaler
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Format conversion
#
# Convert to parquet format for more flexible usage

# %%
pd.read_csv("data/application_record.csv").to_parquet("data/application.parquet", index=False)
pd.read_csv("data/credit_record.csv").to_parquet("data/credit_record.parquet", index=False)

# %%
application = pd.read_parquet("data/application.parquet")
credit_record = pd.read_parquet("data/credit_record.parquet")

# %% [markdown]
# ## Data sample

# %%
application.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0            None
# 1           1                1           0           0            None
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
credit_record.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# ## Creating label

# %% [markdown]
# ### Month balance & status
#
# Month balance:
#
# The month of the extracted data is the starting point, backwards, 0 is the current month, -1 is the previous month, and so on
#
# Status:
#
# 0: 1-29 days past due 1: 30-59 days past due 2: 60-89 days overdue 3: 90-119 days overdue 4: 120-149 days overdue 5: Overdue or bad debts, write-offs for more than 150 days C: paid off that month X: No loan for the month
#
# <font color="red">I will assume that any overdue of 60 or more days corresponds to a default</font>

# %%
defaulted_user_ids = credit_record.query("STATUS not in ['0','1','C','X']")["ID"].unique()

# %%
credit_record_unique = credit_record.drop_duplicates(subset=["ID"],keep="last",ignore_index=True).copy()

# %%
credit_record_unique["LABEL"] = credit_record["ID"].apply(lambda x: 1 if x in defaulted_user_ids else 0)

# %%
credit_record_unique["LABEL"].value_counts(normalize=True)
# Out:
# 0    0.988583
# 1    0.011417
# Name: LABEL, dtype: float64

# %% [markdown]
# ## Duplicates

# %%
len(application.ID.unique())
# Out:
# 438510

# %%
application_duplicates = application[application.duplicated(subset=[col for col in application.columns if col != "ID"], keep=False)]
application_duplicates
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# 5       5008810           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438550  6840100           F            N               Y             0
# 438551  6840102           F            N               Y             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# 5               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438550          135000.0             Pensioner  Secondary / secondary special
# 438551          135000.0             Pensioner  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# 5       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438550             Separated  House / apartment      -22717         365243
# 438551             Separated  House / apartment      -22717         365243
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0            None
# 1                1                1           0           0            None
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# 5                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438550           1                0           0           0            None
# 438551           1                0           0           0            None
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0            None
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# ...                 ...
# 438550              1.0
# 438551              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [423253 rows x 18 columns]

# %%
application_no_duplicates_first = application[~application.duplicated(subset=[col for col in application.columns if col != "ID"], keep="first")]
application_no_duplicates_first
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 7       5008812           F            N               Y             0
# 10      5008815           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 438541  6837707           M            N               Y             0
# 438545  6839651           F            N               Y             3
# 438547  6839917           F            N               Y             0
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 7               283500.0             Pensioner               Higher education
# 10              270000.0               Working               Higher education
# ...                  ...                   ...                            ...
# 438541          202500.0               Working               Higher education
# 438545           99000.0             Pensioner  Secondary / secondary special
# 438547          180000.0             Pensioner               Higher education
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 7                  Separated  House / apartment      -22464         365243
# 10                   Married  House / apartment      -16872           -769
# ...                      ...                ...         ...            ...
# 438541        Civil marriage  House / apartment      -13510          -2309
# 438545  Single / not married  House / apartment      -18832         365243
# 438547               Married  House / apartment      -10966          -2704
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0            None
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 7                1                0           0           0            None
# 10               1                1           1           1     Accountants
# ...            ...              ...         ...         ...             ...
# 438541           1                1           0           0        Laborers
# 438545           1                0           0           0            None
# 438547           1                0           0           0            None
# 438552           1                0           0           0            None
# 438553           1                0           0           0        Laborers
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 2                   2.0
# 3                   1.0
# 7                   1.0
# 10                  2.0
# ...                 ...
# 438541              2.0
# 438545              1.0
# 438547              2.0
# 438552              1.0
# 438553              1.0
#
# [90085 rows x 18 columns]

# %%
len(application_no_duplicates_first.ID.unique())
# Out:
# 90085

# %%
len(credit_record["ID"].unique())
# Out:
# 45985

# %%
len(set(application_no_duplicates_first.ID).intersection(set(credit_record.ID)))
# Out:
# 9709

# %%
duplicate_id_groups = pd.DataFrame(application.groupby(by=[col for col in application.columns if col != "ID"])["ID"].apply(lambda x: list(np.unique(x))).reset_index(drop=True))

# %%
duplicate_id_groups
# Out:
#                                                       ID
# 0                                     [6231976, 6231977]
# 1                            [5126174, 5126175, 5995345]
# 2                            [6618535, 6690062, 6690063]
# 3                                              [6722801]
# 4                                     [5771303, 5771305]
# ...                                                  ...
# 62603  [5135534, 5135535, 5135536, 5135537, 5135538, ...
# 62604  [5949365, 5949366, 5949368, 5949369, 5949370, ...
# 62605  [6272384, 6471231, 6471232, 6471233, 6471234, ...
# 62606  [5342630, 5342633, 5342634, 5342635, 5342637, ...
# 62607                        [5061207, 5061210, 5061211]
#
# [62608 rows x 1 columns]

# %%
pd.options.display.max_rows = 1000

# %%
credit_record.query(f'ID in [5135534, 5135535, 5135536, 5135537, 5135538]').sort_values(["ID","MONTHS_BALANCE"], ascending=False)
# Out:
#              ID  MONTHS_BALANCE STATUS
# 945201  5135538               0      X
# 945202  5135538              -1      X
# 945203  5135538              -2      X
# 945204  5135538              -3      X
# 945205  5135538              -4      X
# 945206  5135538              -5      X
# 505547  5061211             -19      0
# 505548  5061211             -20      0
# 505549  5061211             -21      0
# 505550  5061211             -22      0
# 505551  5061211             -23      0
# 505552  5061211             -24      0
# 505553  5061211             -25      0
# 505554  5061211             -26      0
# 505555  5061211             -27      0
# 505556  5061211             -28      0
# 505557  5061211             -29      1
# 505558  5061211             -30      0
# 505559  5061211             -31      0
# 505560  5061211             -32      0
# 505561  5061211             -33      0
# 505562  5061211             -34      0
# 505563  5061211             -35      0
# 505564  5061211             -36      0
# 505565  5061211             -37      0
# 505566  5061211             -38      0
# 505567  5061211             -39      0
# 505568  5061211             -40      0
# 505569  5061211             -41      0
# 505570  5061211             -42      0
# 505571  5061211             -43      0
# 505520  5061210               0      0
# 505521  5061210              -1      0
# 505522  5061210              -2      0
# 505523  5061210              -3      1
# 505524  5061210              -4      0
# 505525  5061210              -5      0
# 505526  5061210              -6      1
# 505527  5061210              -7      0
# 505461  5061207               0      0
# 505462  5061207              -1      0
# 505463  5061207              -2      0
# 505464  5061207              -3      0
# 505465  5061207              -4      0
# 505466  5061207              -5      0
# 505467  5061207              -6      X
# 505468  5061207              -7      0
# 505469  5061207              -8      X
# 505470  5061207              -9      0
# 505471  5061207             -10      X
# 505472  5061207             -11      0
# 505473  5061207             -12      X
# 505474  5061207             -13      0
# 505475  5061207             -14      X
# 505476  5061207             -15      0
# 505477  5061207             -16      0
# 505478  5061207             -17      0
# 505479  5061207             -18      X
# 505480  5061207             -19      0
# 505481  5061207             -20      0
# 505482  5061207             -21      0
# 505483  5061207             -22      X
# 505484  5061207             -23      0
# 505485  5061207             -24      0
# 505486  5061207             -25      0
# 505487  5061207             -26      X
# 505488  5061207             -27      X
# 505489  5061207             -28      0
# 505490  5061207             -29      0
# 505491  5061207             -30      0
# 505492  5061207             -31      0
# 505493  5061207             -32      0
# 505494  5061207             -33      0
# 505495  5061207             -34      0
# 505496  5061207             -35      0
# 505497  5061207             -36      0
# 505498  5061207             -37      X
# 505499  5061207             -38      0
# 505500  5061207             -39      X
# 505501  5061207             -40      0
# 505502  5061207             -41      X
# 505503  5061207             -42      X
# 505504  5061207             -43      X
# 505505  5061207             -44      X
# 505506  5061207             -45      0
# 505507  5061207             -46      0
# 505508  5061207             -47      X
# 505509  5061207             -48      0
# 505510  5061207             -49      0
# 505511  5061207             -50      0
# 505512  5061207             -51      X
# 505513  5061207             -52      X
# 505514  5061207             -53      X
# 505515  5061207             -54      X
# 505516  5061207             -55      X
# 505517  5061207             -56      X
# 505518  5061207             -57      X
# 505519  5061207             -58      X

# %% [markdown]
# ### Merge applications with credit records

# %%
df = application.merge(credit_record_unique[["ID","LABEL"]], how="inner", on="ID")

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates(subset=["ID"], keep="first", inplace=True)

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0            None
# 1           1                1           0           0            None
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS  LABEL
# 0              2.0      0
# 1              2.0      0
# 2              2.0      0
# 3              1.0      0
# 4              1.0      0

# %%
df["duplicated"] = df[[col for col in df.columns if col != "ID"]].duplicated()

# %%
df.head(100)
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0   5008
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           427500.0               Working               Higher education
# 1           427500.0               Working               Higher education
# 2           112500.0               Working  Secondary / secondary special
# 3           270000.0  Commercial associate  Secondary / secondary special
# 4           270000.0  Commercial associate  Secondary / secondary special
# 5           270000.0  Commercial associate  Secondary / secondary special
# 6           270000.0  Commercial associate  Secondary / secondary special
# 7           283500.0             Pensioner               Higher education
# 8           283500.0             Pensioner               Higher education
# 9           283500.0             Pensioner               Higher education
# 10          270000.0               Working               Higher education
# 11          270000.0               Working               Higher education
# 12          135000.0  Commercial associate  Secondary / secondary special
# 13          135000.0  Commercial associate  Secondary / secondary special
# 14          135000.0  Commercial associate  Secondary / secondary special
# 15          135000.0  Commercial associate  Secondary / secondary special
# 16          135000.0  Commercial associate  Secondary / secondary special
# 17          135000.0  Commercial associate  Secondary / secondary special
# 18          130500.0               Working              Incomplete higher
# 19          130500.0               Working              Incomplete higher
# 20          157500.0               Working  Secondary / secondary special
# 21          157500.0               Working  Secondary / secondary special
# 22          157500.0               Working  Secondary / secondary special
# 23          112500.0               Working  Secondary / secondary special
# 24          112500.0               Working  Secondary / secondary special
# 25          270000.0               Working  Secondary / secondary special
# 26          270000.0               Working  Secondary / secondary special
# 27          405000.0  Commercial associate               Higher education
# 28          405000.0  Commercial associate               Higher education
# 29          405000.0  Commercial associate               Higher education
# 30          405000.0  Commercial associate               Higher education
# 31          405000.0  Commercial associate               Higher education
# 32          405000.0  Commercial associate               Higher education
# 33          112500.0  Commercial associate  Secondary / secondary special
# 34          112500.0  Commercial associate  Secondary / secondary special
# 35          112500.0  Commercial associate  Secondary / secondary special
# 36          112500.0  Commercial associate  Secondary / secondary special
# 37          112500.0  Commercial associate  Secondary / secondary special
# 38          112500.0  Commercial associate  Secondary / secondary special
# 39          112500.0  Commercial associate  Secondary / secondary special
# 40          112500.0  Commercial associate  Secondary / secondary special
# 41          135000.0               Working  Secondary / secondary special
# 42          135000.0               Working  Secondary / secondary special
# 43          135000.0               Working  Secondary / secondary special
# 44          135000.0               Working  Secondary / secondary special
# 45          135000.0               Working  Secondary / secondary special
# 46          135000.0               Working  Secondary / secondary special
# 47          135000.0               Working  Secondary / secondary special
# 48          135000.0               Working  Secondary / secondary special
# 49          135000.0               Working  Secondary / secondary special
# 50          135000.0               Working  Secondary / secondary special
# 51          135000.0               Working  Secondary / secondary special
# 52          135000.0               Working  Secondary / secondary special
# 53          135000.0               Working  Secondary / secondary special
# 54          135000.0               Working  Secondary / secondary special
# 55          135000.0               Working  Secondary / secondary special
# 56          211500.0         State servant  Secondary / secondary special
# 57          211500.0         State servant  Secondary / secondary special
# 58          360000.0  Commercial associate  Secondary / secondary special
# 59          126000.0  Commercial associate               Higher education
# 60          126000.0  Commercial associate               Higher education
# 61          126000.0  Commercial associate               Higher education
# 62          126000.0  Commercial associate               Higher education
# 63          126000.0  Commercial associate               Higher education
# 64          126000.0  Commercial associate               Higher education
# 97           1                0           0           0        Laborers
# 98           1                0           0           0        Laborers
# 99           1                0           0           0        Laborers
#
#     CNT_FAM_MEMBERS  LABEL  duplicated
# 0               2.0      0       False
# 1               2.0      0        True
# 2               2.0      0       False
# 3               1.0      0       False
# 4               1.0      0        True
# 5               1.0      0        True
# 6               1.0      0        True
# 7               1.0      0       False
# 8               1.0      0        True
# 9               1.0      0        True
# 10              2.0      0       False
# 11              2.0      0        True
# 12              2.0      0       False
# 13              2.0      0        True
# 14              2.0      0        True
# 15              2.0      0        True
# 16              2.0      0        True
# 17              2.0      0        True
# 18              2.0      0       False
# 19              2.0      0        True
# 20              2.0      0       False
# 21              2.0      0        True
# 22              2.0      0        True
# 23              2.0      0       False
# 24              2.0      0        True
# 25              5.0      0       False
# 26              5.0      0        True
# 27              3.0      0       False
# 28              3.0      0        True
# 29              3.0      0        True
# 30              3.0      0        True
# 31              3.0      0        True
# 32              3.0      0        True
# 33              2.0      0       False
# 34              2.0      0        True
# 35              2.0      0        True
# 36              2.0      0        True
# 37              2.0      0        True
# 38              2.0      0        True
# 39              2.0      0        True
# 40              2.0      0        True
# 41              4.0      0       False
# 42              4.0      0        True
# 43              4.0      0        True
# 44              4.0      0        True
# 45              4.0      0        True
# 46              4.0      0        True
# 47              4.0      0        True
# 48              4.0      0        True
# 49              4.0      0        True
# 50              4.0      0        True
# 51              4.0      0        True
# 52              4.0      0        True
# 53              4.0      0        True
# 54              4.0      0        True
# 55              4.0      0        True
# 56              3.0      0       False
# 57              3.0      0        True
# 58              2.0      0       False
# 59              4.0      0       False
# 60              4.0      0        True
# 61              4.0      0        True
# 62              4.0      0        True
# 63              4.0      0        True
# 64              4.0      0        True
# 65              4.0      0        True
# 66              4.0      0        True
# 67              4.0      0        True
# 68              4.0      0        True
# 69              1.0      0       False
# 70              1.0      0       False
# 71              1.0      0        True
# 72              1.0      0        True
# 73              1.0      0        True
# 74              1.0      0       False
# 75              1.0      0        True
# 76              1.0      0        True
# 77              1.0      0        True
# 78              1.0      0        True
# 79              1.0      0        True
# 80              1.0      0        True
# 81              1.0      0        True
# 82              1.0      0        True
# 83              1.0      0        True
# 84              1.0      0        True
# 85              1.0      0        True
# 86              1.0      0        True
# 87              1.0      0        True
# 88              1.0      0        True
# 89              1.0      0        True
# 90              1.0      0        True
# 91              1.0      0        True
# 92              1.0      0        True
# 93              1.0      0        True
# 94              1.0      0        True
# 95              1.0      0        True
# 96              1.0      0        True
# 97              1.0      0        True
# 98              1.0      0        True
# 99              1.0      0        True

# %%
application[[col for col in application.columns if col != "ID"]].duplicated().sum()
# Out:
# 348472

# %% [markdown]
# ## Split datasets

# %%
X = df.iloc[:,1:-1] 
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.15, random_state=42)

# %%
y_train.value_counts(normalize=True)
# Out:
# True     0.732187
# False    0.267813
# Name: duplicated, dtype: float64

# %% [markdown]
# ## Dump datasets

# %%
pd.concat([X_train, y_train], axis=1).to_parquet(f"data/{sts.DATASET_TRAIN_FILENAME}", index=False)
pd.concat([X_test, y_test], axis=1).to_parquet(f"data/{sts.DATASET_VALIDATION_FILENAME}", index=False)
